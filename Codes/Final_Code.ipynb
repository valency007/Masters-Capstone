# %%
#Importing libraries and a public daatset for tweets
import pandas as pd
import nltk
nltk.download('punkt')
#tweets=pd.read_csv('tweet_text.csv')
tweets=pd.read_csv('Public_Dataset.csv')
ss=tweets
# Out:
# [nltk_data] Downloading package punkt to /Users/sriramswa/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#Import second tweet dataset
tweets_1=pd.read_csv('tweet_text.csv')
ss1=tweets_1
ss1.head()
# Out:
#   web-scraper-order                                            content
# 0   1557300516-3064  Psychedelic #Mushrooms Could Be The Next Break...
# 1   1557300516-2778  Talking to loved ones about #depression allevi...
# 2   1557300516-2651  FDA panels vote to recommend approval of esket...
# 3   1557300516-2792  I am eager and anxious to be trying a course o...
# 4   1557300516-2967  I lived w/ #depression for 6 years before seek...

# %%
#Import third tweet dataset
tweets_2=pd.read_csv('Input/depressive_tweets_2.csv')
ss2=tweets_2
ss2.head()
# Out:
#    Unnamed: 0                                            message  label
# 0         106  just had a real good moment. i missssssssss hi...      0
# 1         217         is reading manga  http://plurk.com/p/mzp1e      0
# 2         220  @comeagainjen http://twitpic.com/2y2lx - http:...      0
# 3         288  @lapcat Need to send 'em to my accountant tomo...      0
# 4         540      ADD ME ON MYSPACE!!!  myspace.com/LookThunder      0

# %%
#Performing pre-processing for the first tweet dataset
from textblob import TextBlob
import re
ss.content = ss['content'].fillna("")
#converting to lowercase
ss['text_process'] = ss['content'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#Removing punctuation
ss['text_process'] = ss['text_process'].str.replace('[^\w\s]','')


#Removal of stopwords
#from nltk.corpus import stopwords
#stop = stopwords.words('english')
#ss['text_process'] = ss['text_process'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

#Removing numerics
ss['text_process'] = ss['text_process'].apply(lambda x: " ".join(x for x in x.split() if not x.isdigit()))

#Removing non-english words
import nltk
nltk.download('words')
words = set(nltk.corpus.words.words())

#Removing non-english words
# keep only words
regex_pat = re.compile(r'[^a-zA-Z\s]', flags=re.IGNORECASE)
ss.text_process = ss.text_process.replace(regex_pat, '')


ss['text_process']=ss['text_process'].apply(lambda x: " ".join(x for x in nltk.wordpunct_tokenize(x)))

#Lemitization

#from textblob import Word
#ss['text_process'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))


#Removing https
ss['text_process'] = ss['text_process'].apply(lambda x: " ".join(x for x in x.split() if not x.startswith('https')))
ss['text_process'].head()
# Out:
# [nltk_data] Downloading package words to /Users/sriramswa/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 0    sudell i love that show shan lets pretend we r...
# 1                          thisisryanross i wanna come
# 2    linnetwoods im sure i will grace yo daughter i...
# 3    picked up carolines new dog shes sweet eating ...
# 4    trentreznor but thats what umbrellas and spf l...
# Name: text_process, dtype: object

# %%
#For ss1
#Performing pre-processing for the second tweet dataset
from textblob import TextBlob
import re
ss1.content = ss1['content'].fillna("")
#converting to lowercase
ss1['text_process'] = ss1['content'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#Removing punctuation
ss1['text_process'] = ss1['text_process'].str.replace('[^\w\s]','')


#Removal of stopwords
#from nltk.corpus import stopwords
#stop = stopwords.words('english')
#ss['text_process'] = ss['text_process'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

#Removing numerics
ss1['text_process'] = ss1['text_process'].apply(lambda x: " ".join(x for x in x.split() if not x.isdigit()))

#Removing non-english words
import nltk
nltk.download('words')
words = set(nltk.corpus.words.words())

#Removing non-english words
# keep only words
regex_pat = re.compile(r'[^a-zA-Z\s]', flags=re.IGNORECASE)
ss1.text_process = ss1.text_process.replace(regex_pat, '')


ss1['text_process']=ss1['text_process'].apply(lambda x: " ".join(x for x in nltk.wordpunct_tokenize(x)))

#Lemitization

#from textblob import Word
#ss['text_process'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))


#Removing https
ss1['text_process'] = ss['text_process'].apply(lambda x: " ".join(x for x in x.split() if not x.startswith('https')))
ss1['text_process'].head()
# Out:
# [nltk_data] Downloading package words to /Users/sriramswa/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 0    sudell i love that show shan lets pretend we r...
# 1                          thisisryanross i wanna come
# 2    linnetwoods im sure i will grace yo daughter i...
# 3    picked up carolines new dog shes sweet eating ...
# 4    trentreznor but thats what umbrellas and spf l...
# Name: text_process, dtype: object

# %%
#For ss1
#Performing pre-processing for the third tweet dataset

from textblob import TextBlob
import re
ss2.content = ss2['message'].fillna("")
#converting to lowercase
ss2['text_process'] = ss2['message'].apply(lambda x: " ".join(x.lower() for x in x.split()))

#Removing punctuation
ss2['text_process'] = ss2['text_process'].str.replace('[^\w\s]','')


#Removal of stopwords
#from nltk.corpus import stopwords
#stop = stopwords.words('english')
#ss['text_process'] = ss['text_process'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

#Removing numerics
ss2['text_process'] = ss2['text_process'].apply(lambda x: " ".join(x for x in x.split() if not x.isdigit()))

#Removing non-english words
import nltk
nltk.download('words')
words = set(nltk.corpus.words.words())

#Removing non-english words
# keep only words
regex_pat = re.compile(r'[^a-zA-Z\s]', flags=re.IGNORECASE)
ss2.text_process = ss2.text_process.replace(regex_pat, '')


ss2['text_process']=ss2['text_process'].apply(lambda x: " ".join(x for x in nltk.wordpunct_tokenize(x)))

#Lemitization

#from textblob import Word
#ss['text_process'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))


#Removing https
ss2['text_process'] = ss2['text_process'].apply(lambda x: " ".join(x for x in x.split() if not x.startswith('https')))
ss2['text_process'].head()
# Out:
# /Users/sriramswa/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#
# [nltk_data] Downloading package words to /Users/sriramswa/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 0    just had a real good moment i missssssssss him...
# 1                   is reading manga httpplurkcompmzpe
# 2    comeagainjen httptwitpiccomylx httpwwwyoutubec...
# 3    lapcat need to send em to my accountant tomorr...
# 4              add me on myspace myspacecomlookthunder
# Name: text_process, dtype: object

# %%
#Latent Dirichlet Allocation (LDA)
'''
Loading Gensim and nltk libraries
'''
# pip install gensim
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(400)

#Further pre-processing-lemmatization and stemming for the tweets

stemmer = SnowballStemmer("english")
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
          
    return result

# %%
#Passing the first tweet dataset to the pre-process function.
processed_docs = []

for doc in ss.text_process.tolist():
    processed_docs.append(preprocess(doc))
    
'''
Preview 'processed_docs'
'''
print(processed_docs)

#Passing the second tweet dataset to the pre-process function.
processed_docs1 = []

for doc in ss1.text_process.tolist():
    processed_docs1.append(preprocess(doc))
    
'''
Preview 'processed_docs'
'''
print(processed_docs1)


#Passing the third tweet dataset to the pre-process function.
processed_docs2 = []

for doc in ss2.text_process.tolist():
    processed_docs2.append(preprocess(doc))
    
'''
Preview 'processed_docs'
'''
print(processed_docs2)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...

# %% [markdown]
# # Dictionary

# %%
'''
Create a dictionary from 'processed_docs','processed_docs1' and 'processed_docs2' containing the number of times 
a word appears in the training set using gensim.corpora.Dictionary and call it 'dictionary','dictionary1' and 
'dictionary2' for the three dataset
'''
dictionary = gensim.corpora.Dictionary(processed_docs)
dictionary1 = gensim.corpora.Dictionary(processed_docs1)
dictionary2 = gensim.corpora.Dictionary(processed_docs1)

# %%
'''
Remove very rare and very common words:

- words appearing less than 15 times
- words appearing in more than 10% of all documents
'''
dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
dictionary1.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
dictionary2.filter_extremes(no_below=10, no_above=0.1, keep_n= 100000)

# %%
'''
Create the Bag-of-words model for each document i.e for each document we create a dictionary reporting how many
words and how many times those words appear. 
Bag-of-words format = list of (token_id, token_count) 2-tuples
'''
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus1 = [dictionary1.doc2bow(doc) for doc in processed_docs1]
bow_corpus2 = [dictionary1.doc2bow(doc) for doc in processed_docs1]

# %%
'''
Training the lda model using gensim.models.LdaMulticore 
'''

lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 3, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 5)

# %%
'''
Updating the LDA model with the other two bag of words corpuses derived out of the remaining two datasets
'''

lda_model.update(bow_corpus1)

lda_model.update(bow_corpus2)

# %%
'''
Topics are identified based on the distribution of words per tweet and the weightage of the words 
'''
Topic=['Illness','Relational','Prescriptive']
for idx, topic in lda_model.print_topics():
    print("Topic: {} \nWords: {}".format(Topic[idx], topic ))
    print("\n")
# Out:
# Topic: Illness
# Words: 0.064*"umbrella" + 0.061*"date" + 0.056*"lunch" + 0.051*"wanna" + 0.042*"sure" + 0.037*"doubl" + 0.035*"rock" + 0.027*"everybodi" + 0.027*"daughter" + 0.026*"shes"
#
#
# Topic: Relational
# Words: 0.129*"pretend" + 0.107*"tell" + 0.093*"let" + 0.017*"health" + 0.016*"peopl" + 0.015*"dont" + 0.013*"love" + 0.012*"ill" + 0.011*"know" + 0.009*"like"
#
#
# Topic: Prescriptive
# Words: 0.244*"grace" + 0.087*"eat" + 0.011*"help" + 0.011*"stress" + 0.009*"disord" + 0.007*"suffer" + 0.005*"caus" + 0.005*"peopl" + 0.005*"ill" + 0.005*"like"

# %%
'''
Identifying the probability of words for every topic and transforming them as the feature for training the model
'''
a=lda_model.get_topic_terms(1)
c=pd.DataFrame(a)
d=c.T
d.columns=d.iloc[0]
top1=d[1:]

a=lda_model.get_topic_terms(0)
c=pd.DataFrame(a)
d=c.T
d.columns=d.iloc[0]
top0=d[1:]

a=lda_model.get_topic_terms(2)
c=pd.DataFrame(a)
d=c.T
d.columns=d.iloc[0]
top2=d[1:]


top2
# Out:
# 0    13.0      16.0    222.0     630.0     3504.0    1999.0    920.0   \
# 1  0.244095  0.087362  0.0108  0.010651  0.009221  0.007212  0.005488
#
# 0    60.0      3252.0    68.0
# 1  0.005337  0.005253  0.005074

# %%
'''
Creating the dictionary of probability distribution of words per topic
'''
#Topic: Illness 
#Words: 0.222*"pretend" + 0.182*"care" + 0.172*"educ" + 0.100*"eat" + 0.030*"time" + 0.017*"let" + 0.003*"peopl" + 0.003*"health" + 0.003*"ill" + 0.002*"help"


#Topic: Relational 
#Words: 0.075*"draw" + 0.073*"date" + 0.067*"umbrella" + 0.061*"daughter" + 0.058*"lunch" + 0.043*"famili" + 0.040*"rent" + 0.032*"mayb" + 0.027*"toe" + 0.026*"love"


#Topic: Prescriptive 
#Words: 0.101*"that" + 0.083*"pictur" + 0.065*"hello" + 0.065*"impress" + 0.062*"rock" + 0.059*"watch" + 0.055*"haha" + 0.055*"wanna" + 0.040*"shes" + 0.040*"trentreznor"


#top0.columns=["pretend","care","educ","eat","time","let","peopl","health","ill","help"]
top0.rename(columns={6.0: 'Pretend', 48.0: 'care',59.0:"educ",16.0:"eat",58.0:"time",4.0:"let",62.0:"peopl",639.0:"health",4079.0:"ill",239.0:"help"}, inplace=True)

top1.rename(columns={31.0:"draw",0.0:"date",23.0:"umbrella",12.0:"daughter",17.0:"lunch",2.0:"famili",7.0:"rent" ,32.0:"mayb",34.0:"toe",5.0:"love"},inplace=True)
top2.rename(columns={21.0:"that",33.0:"pictur",3.0:"hello",14.0:"impress",25.0:"rock",9.0:"watch",27.0:"haha",11.0:"wanna",19.0:"shes",22.0:"trentreznor"},inplace=True)
# Out:
# /Users/sriramswa/anaconda3/lib/python2.7/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
'''
Labeling the tweets according to the topics 0,1 and 2
'''
top0['Class']='Illness'
top1['Class']='Prescriptive'
top2['Class']='Relational'
# Out:
# /Users/sriramswa/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
b=lda_model.get_topics()
pd.DataFrame(b)
# Out:
#        0         1         2         3         4         5         6     \
# 0  0.061475  0.036510  0.025412  0.022052  0.000005  0.022379  0.002208
# 1  0.000396  0.000015  0.009237  0.000014  0.093377  0.013449  0.129153
# 2  0.000167  0.000065  0.000444  0.000018  0.000019  0.000108  0.002284
#
#        7         8         9     ...      3795      3796      3797      3798  \
# 0  0.015641  0.000476  0.019521  ...  0.000003  0.000003  0.000003  0.000028
# 1  0.000015  0.106698  0.000014  ...  0.000242  0.000019  0.000082  0.000013
# 2  0.000050  0.000514  0.000019  ...  0.000017  0.000176  0.000020  0.000017
#
#        3799      3800      3801      3802      3803      3804
# 0  0.000028  0.000028  0.000028  0.000028  0.000028  0.000003
# 1  0.000013  0.000013  0.000013  0.000013  0.000013  0.000013
# 2  0.000017  0.000017  0.000017  0.000017  0.000017  0.000181
#
# [3 rows x 3805 columns]

# %% [markdown]
# # Testing

# %%
unseen_document=pd.read_csv('saved_tweets.csv')
test1=pd.read_csv('Input/dep_tweets_treatment_1.csv')
test_tweet=unseen_document

test2=pd.read_excel('treatment_tweets_new.xlsx')
test_tweet.text[1]
# Out:
# 'Social media causes youth depression, survey says https://t.co/P80vtOHZWJ'

# %%
#Rating the tweet to the top topic based on the %Strength by testing them using LDA model
test_tweet['Class']=''
test_tweet['%Strength']=''

for i in range(len(test_tweet.text)):
    tmp=[]
    for doc in test_tweet.text[i].split():
        
        tmp.append(preprocess(doc))
    t=unicode((np.concatenate(tmp)))

# Data preprocessing step for the unseen document
#bow_vector = dictionary.doc2bow(preprocess(processed_docs_test))

    bow_vector = dictionary.doc2bow(preprocess(t))
    high=[]
    for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
        high.append(score)
    print("Score: {}\t Topic: {}\n Words: {}".format(score,Topic[index],lda_model.print_topic(index, 10)))
    
    h_ind=np.argmax(high)
    Topic[h_ind]
    #test_tweet.iloc[i,-1]=score[h_ind]
    test_tweet.iloc[i,-2]=Topic[index]
    test_tweet.iloc[i,-1]=max(high)*100
# Out:
# Score: 0.0607806444168	 Topic: Illness
#  Words: 0.064*"umbrella" + 0.061*"date" + 0.056*"lunch" + 0.051*"wanna" + 0.042*"sure" + 0.037*"doubl" + 0.035*"rock" + 0.027*"everybodi" + 0.027*"daughter" + 0.026*"shes"
# Score: 0.05556024611	 Topic: Illness
#  Words: 0.064*"umbrella" + 0.061*"date" + 0.056*"lunch" + 0.051*"wanna" + 0.042*"sure" + 0.037*"doubl" + 0.035*"rock" + 0.027*"everybodi" + 0.027*"daughter" + 0.026*"shes"
# Score: 0.0908279567957	 Topic: Prescriptive
#  Words: 0.244*"grace" + 0.087*"eat" + 0.011*"help" + 0.011*"stress" + 0.009*"disord" + 0.007*"suffer" + 0.005*"caus" + 0.005*"peopl" + 0.005*"ill" + 0.005*"like"
# Score: 0.0870138853788	 Topic: Relational
#  Words: 0.129*"pretend" + 0.107*"tell" + 0.093*"let" + 0.017*"health" + 0.016*"peopl" + 0.015*"dont" + 0.013*"love" + 0.012*"ill" + 0.011*"know" + 0.009*"like"
# Score: 0.118132323027	 Topic: Relational
# ...

# %%
#Rating the tweet from another dataset to the top topic based on the %Strength by testing them using LDA model
test1['Class']=''
test1['%Strength']=''

for i in range(len(test1.content)):
    tmp=[]
    for doc in test1.content[i].split():
        
        tmp.append(preprocess(doc))
    t=unicode((np.concatenate(tmp)))

# Data preprocessing step for the unseen document
#bow_vector = dictionary.doc2bow(preprocess(processed_docs_test))

    bow_vector = dictionary.doc2bow(preprocess(t))
    high=[]
    for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
        high.append(score)
    print("Score: {}\t Topic: {}\n Words: {}".format(score,Topic[index],lda_model.print_topic(index, 10)))
    
    h_ind=np.argmax(high)
    Topic[h_ind]
    #test_tweet.iloc[i,-1]=score[h_ind]
    test1.iloc[i,-2]=Topic[index]
    test1.iloc[i,-1]=max(high)*100
# Out:
# Score: 0.0467783734202	 Topic: Relational
#  Words: 0.129*"pretend" + 0.107*"tell" + 0.093*"let" + 0.017*"health" + 0.016*"peopl" + 0.015*"dont" + 0.013*"love" + 0.012*"ill" + 0.011*"know" + 0.009*"like"
# Score: 0.201367050409	 Topic: Relational
#  Words: 0.129*"pretend" + 0.107*"tell" + 0.093*"let" + 0.017*"health" + 0.016*"peopl" + 0.015*"dont" + 0.013*"love" + 0.012*"ill" + 0.011*"know" + 0.009*"like"
# Score: 0.0419569201767	 Topic: Relational
#  Words: 0.129*"pretend" + 0.107*"tell" + 0.093*"let" + 0.017*"health" + 0.016*"peopl" + 0.015*"dont" + 0.013*"love" + 0.012*"ill" + 0.011*"know" + 0.009*"like"
# Score: 0.0333852469921	 Topic: Illness
#  Words: 0.064*"umbrella" + 0.061*"date" + 0.056*"lunch" + 0.051*"wanna" + 0.042*"sure" + 0.037*"doubl" + 0.035*"rock" + 0.027*"everybodi" + 0.027*"daughter" + 0.026*"shes"
# Score: 0.0862910449505	 Topic: Illness
# ...

# %%
#Rating the tweet from another dataset to the top topic based on the %Strength by testing them using LDA model
'''
test tweet for comparing with neural networks
'''
test2['Class']=''
test2['%Strength']=''

for i in range(len(test2.content)):
    tmp=[]
    for doc in test2.content[i].split():
        
        tmp.append(preprocess(doc))
    t=unicode((np.concatenate(tmp)))

# Data preprocessing step for the unseen document
#bow_vector = dictionary.doc2bow(preprocess(processed_docs_test))

    bow_vector = dictionary.doc2bow(preprocess(t))
    high=[]
    for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
        high.append(score)
    print("Score: {}\t Topic: {}\n Words: {}".format(score,Topic[index],lda_model.print_topic(index, 10)))
    
    h_ind=np.argmax(high)
    Topic[h_ind]
    #test_tweet.iloc[i,-1]=score[h_ind]
    test2.iloc[i,-2]=Topic[index]
    test2.iloc[i,-1]=max(high)*100
# Out:
# Score: 0.0467801094055	 Topic: Relational
#  Words: 0.129*"pretend" + 0.107*"tell" + 0.093*"let" + 0.017*"health" + 0.016*"peopl" + 0.015*"dont" + 0.013*"love" + 0.012*"ill" + 0.011*"know" + 0.009*"like"
# Score: 0.201408863068	 Topic: Relational
#  Words: 0.129*"pretend" + 0.107*"tell" + 0.093*"let" + 0.017*"health" + 0.016*"peopl" + 0.015*"dont" + 0.013*"love" + 0.012*"ill" + 0.011*"know" + 0.009*"like"
# Score: 0.0419533774257	 Topic: Relational
#  Words: 0.129*"pretend" + 0.107*"tell" + 0.093*"let" + 0.017*"health" + 0.016*"peopl" + 0.015*"dont" + 0.013*"love" + 0.012*"ill" + 0.011*"know" + 0.009*"like"
# Score: 0.0333852469921	 Topic: Illness
#  Words: 0.064*"umbrella" + 0.061*"date" + 0.056*"lunch" + 0.051*"wanna" + 0.042*"sure" + 0.037*"doubl" + 0.035*"rock" + 0.027*"everybodi" + 0.027*"daughter" + 0.026*"shes"
# Score: 0.0862910822034	 Topic: Illness
# ...

# %%
#Merging all the tweets with the right topics
merged=pd.merge(test_tweet,top0, on='Class')
merged1=pd.merge(test_tweet,top1, on='Class')
merged2=pd.merge(test_tweet,top2, on='Class')
merged_all=pd.concat([merged,merged1,merged2])
merged_all
# Out:
# /Users/sriramswa/anaconda3/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
#           0.0      1.0  4.0  6.0  8.0      11.0     12.0      13.0     15.0  \
# 0    0.061475  0.03651  NaN  NaN  NaN  0.051145  0.02701       NaN  0.04183
# 1    0.061475  0.03651  NaN  NaN  NaN  0.051145  0.02701       NaN  0.04183
# 2    0.061475  0.03651  NaN  NaN  NaN  0.051145  0.02701       NaN  0.04183
# 3    0.061475  0.03651  NaN  NaN  NaN  0.051145  0.02701       NaN  0.04183
# 4    0.061475  0.03651  NaN  NaN  NaN  0.051145  0.02701       NaN  0.04183
# 5    0.061475  0.03651  NaN  NaN  NaN  0.051145  0.02701       NaN  0.04183
# 6    0.061475  0.03651  NaN  NaN  NaN  0.051145  0.02701       NaN  0.04183
# ...

# %%
test2
# Out:
#                handle                                    name  \
# 0          @AmberLyon                              Amber Lyon
# 1    @ThePaintedBrain                        Painted Brain LA
# 2           @Medscape                                Medscape
# 3        @CHarrisBond                    Courtenay HarrisBond
# 4    @NAMICommunicate                                    NAMI
# 5    @NAMICommunicate                                    NAMI
# 6     @medical_xpress                          Medical Xpress
# 7        @DBSAlliance                                    DBSA
# 8           @Dr_Lanie                        Lanie Spaedy, MD
# 9         @AnnalsofIM                       Annals of Int Med
# 10       @StanfordMed                       Stanford Medicine
# 11       @DrHowardLiu                              Howard Liu
# 12         @akhuthera                       Akhu Therapeutics
# 13          @vinylarm                          The Rising Sun
# ...

# %%
#Copying the final dataframe (merged_all) to the csv file for further visualisation analysis
test1.to_csv('Output/Illness_Emotions_Relations/class_file2.csv')
test_tweet.to_csv('Output/Illness_Emotions_Relations/class_file1.csv')
merged_all.to_csv('Output/Illness_Emotions_Relations/class_file3.csv')

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf8')

test2.content = test2['content'].fillna("")
test2.text_process = test2['text_process'].fillna("")
test2.Tweet = test2['Tweet'].fillna("")
test2.to_csv('Output/Illness_Emotions_Relations/treatment_tweets_new1.csv')

# %%
pd.set_option('display.max_colwidth', 200)
merged_all['text'] = merged_all['text'].str.wrap(200)
merged_all.loc[30,['text','Class']]
# Out:
#                                                                                                                                               text  \
# 30    RT @KokeReport: Omar Upset Minnesota Democrats Want Her Removed From Congress, Do You Want To Remove Her From Congress ? https://t.co/4CHK5…
# 30  RT @yvonnethebird12: My dad has been really depressed ever since our family dog passed away and today I surprised him with a new puppy 😊😭 h…
# 30                                          RT @b1bygurll: My depression when it see’s me happy for more than five minutes https://t.co/8FJMsabv4w
#
#            Class
# 30       Illness
# 30  Prescriptive
# 30    Relational

# %% [markdown]
# # Visualisation

# %%
# Visualize the topics
import pyLDAvis
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, bow_corpus, dictionary)
vis
# Out:
# /Users/sriramswa/anaconda3/lib/python2.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 2      58.309780        1       1 -0.227412  0.245514
# 1      31.192436        1       2 -0.141402 -0.286902
# 0      10.497787        1       3  0.368815  0.041387, topic_info=     Category           Freq         Term          Total  loglift  logprob
# 3325  Default  164649.000000          eat  164649.000000  30.0000  30.0000
# 320   Default   42732.000000      pretend   42732.000000  29.0000  29.0000
# 129   Default   32137.000000         tell   32137.000000  28.0000  28.0000
# ...

# %% [markdown]
# # Passing the Ground Truth Labels from LDA and predict new data using Neural Networks

# %%
#Initialization of Libraries
import numpy as np
import pandas as pd
import sys
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding, Flatten
from keras.layers import Conv1D, GlobalMaxPooling1D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
import utils
from keras.preprocessing.sequence import pad_sequences



tweets=pd.read_csv('Output/Illness_Emotions_Relations/treatment_tweets_new1.csv')

# %%
tweets['Class']=tweets['Class'].replace(np.NaN,'Prescriptive')
tweets.groupby(['Class']).count()
# Out:
#               Unnamed: 0  handle  name  content  replies  retweets  favorites  \
# Class
# Illness              284     284   284      284      132       275        272
# Prescriptive         463     462   462      462      212       435        430
# Relational           117     117   117      117       56       111        112
#
#               published_date  text_process  Sentiment  Tweet  %Strength
# Class
# Illness                  284           284        284    284        284
# Prescriptive             461           462        463    462          4
# Relational               117           117        117    117        117

# %%
tweets['Class1']=tweets['Class'].replace(['Illness','Relational','Prescriptive'],[0,1,2])

tweets.content = tweets['content'].fillna("")
tweets.text_process = tweets['text_process'].fillna("")
tweets.head()
# Out:
#    Unnamed: 0            handle                  name  \
# 0           0        @AmberLyon            Amber Lyon
# 1           1  @ThePaintedBrain      Painted Brain LA
# 2           2         @Medscape              Medscape
# 3           3      @CHarrisBond  Courtenay HarrisBond
# 4           4  @NAMICommunicate                  NAMI
#
#                                              content  replies retweets  \
# 0  Psychedelic #Mushrooms Could Be The Next Break...      2.0       55
# 1  Talking to loved ones about #depression allevi...      NaN       15
# 2  FDA panels vote to recommend approval of esket...      1.0       14
# 3  I am eager and anxious to be trying a course o...      2.0        3
# 4  I lived w/ #depression for 6 years before seek...      NaN       13
#
#   favorites          published_date  \
# 0        52  12:12 PM - 27 Dec 2015
# 1        22   2:55 PM - 11 Feb 2018
# 2        23  11:09 AM - 13 Feb 2019
# 3        20   7:43 AM - 26 Dec 2017
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

vectorizer = CountVectorizer(min_df=0, lowercase=False)
vectorizer.fit((tweets.text_process).apply(lambda x: np.str_(x)))
vectorizer.vocabulary_
vectorizer.transform((tweets.text_process).apply(lambda x: np.str_(x))).toarray()
vectorizer.fit(tweets.Tweet.apply(lambda x: np.str_(x)))

#x = v.fit_transform(df['Review'].apply(lambda x: np.str_(x)))
# Out:
# CountVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=False, max_df=1.0, max_features=None, min_df=0,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
from sklearn.model_selection import train_test_split
import numpy as np

sentences = tweets['text_process'].values
y = tweets['Class1'].values

sentences_train, sentences_test, y_train, y_test = train_test_split(sentences, y, test_size=0.2, random_state=1000)

from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
vectorizer.fit(sentences_train.astype('U'))
#X_train = vectorizer.fit_transform(sentences_train.apply(lambda x: np.str_(x)))

X_train = vectorizer.transform(sentences_train)
X_test  = vectorizer.transform(sentences_test)
X_train
# Out:
# <691x3086 sparse matrix of type '<type 'numpy.int64'>'
# 	with 8282 stored elements in Compressed Sparse Row format>

# %%
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(sentences_train)

X_train = tokenizer.texts_to_sequences(sentences_train)
X_test = tokenizer.texts_to_sequences(sentences_test)

vocab_size = len(tokenizer.word_index) + 1  # Adding 1 because of reserved 0 index

print(sentences_train[2])
print(X_train[2])
# Out:
# physicians recommended cannabis treatment depression since httpmmjnewsthw pictwittercomuzghsft
# [69, 70, 28, 2, 1, 53, 61, 896]

# %%
y_test
# Out:
# array([2, 2, 0, 1, 2, 1, 2, 2, 2, 2, 0, 2, 1, 0, 2, 0, 0, 2, 2, 0, 2, 0,
#        2, 1, 1, 0, 0, 0, 0, 0, 2, 2, 0, 0, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2,
#        0, 2, 0, 2, 0, 0, 0, 0, 2, 2, 2, 2, 1, 0, 0, 0, 2, 2, 2, 0, 2, 1,
#        2, 0, 0, 2, 1, 2, 0, 2, 2, 0, 1, 2, 2, 2, 0, 0, 1, 2, 2, 0, 2, 0,
#        0, 2, 0, 2, 2, 0, 2, 0, 0, 2, 2, 2, 0, 1, 2, 1, 2, 1, 2, 0, 0, 0,
#        2, 0, 2, 2, 0, 2, 2, 2, 1, 1, 2, 0, 0, 1, 0, 1, 0, 2, 0, 2, 2, 1,
#        1, 2, 2, 2, 2, 2, 0, 2, 0, 0, 0, 2, 0, 0, 2, 0, 1, 2, 2, 2, 2, 2,
#        0, 0, 2, 0, 2, 2, 0, 0, 0, 2, 0, 2, 2, 2, 2, 0, 2, 2, 0])

# %%
from keras.preprocessing.sequence import pad_sequences

maxlen = 500

X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)
X_train.shape
# Out:
# (691, 500)

# %%
from keras.models import Sequential
from keras import layers
embedding_dim = 100

model = Sequential()
model.add(layers.Embedding(vocab_size, embedding_dim, input_length=maxlen))
model.add(layers.Conv1D(128, 7, activation='relu'))
model.add(layers.GlobalMaxPooling1D())
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From /Users/sriramswa/anaconda3/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_1 (Embedding)      (None, 500, 100)          309900
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 494, 128)          89728
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# _________________________________________________________________
# ...

# %%
import numpy as np
history = model.fit((X_train), (y_train),
                    epochs=20,
                    verbose=False,
                    validation_data=(X_test, y_test),
                    batch_size=10)
# Out:
# WARNING:tensorflow:From /Users/sriramswa/anaconda3/lib/python2.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /Users/sriramswa/anaconda3/lib/python2.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %%
loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# Training Accuracy: 0.1375
# Testing Accuracy:  0.1272

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression()
classifier.fit(X_train, y_train)
score = classifier.score(X_test, y_test)

print("Accuracy:", score)
# Out:
# ('Accuracy:', 0.45664739884393063)
# /Users/sriramswa/anaconda3/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
from sklearn.metrics import confusion_matrix
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[10,  1, 53],
#        [ 4,  3, 15],
#        [18,  3, 66]])
